# %%
import pandas as pd
from load_csv import load
import matplotlib.pyplot as plt

# %%
df = load("../life_expectancy_years.csv")

df
# Out:
# Loading dataset of dimensions df.shape
# Loading dataset of dimensions (195, 302)
#                   country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0             Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1
# 1                  Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0
# 2                 Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4
# 3                 Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    United Arab Emirates  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 190                 Samoa  25.4  25.4  25.4  25.4  25.4  25.4  25.4  25.4
# 191                 Yemen  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4
# 192          South Africa  33.5  33.5  33.5  33.5  33.5  33.5  33.5  33.5
# 193                Zambia  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6
# 194              Zimbabwe  33.7  33.7  33.7  33.7  33.7  33.7  33.7  33.7
# ...

# %%
df[df['country'] == 'Spain']
# Out:
#    country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  2091  \
# 53   Spain  29.5  29.5  29.5  29.5  29.5  29.5  29.5  29.5  29.5  ...  91.3
#
#     2092  2093  2094  2095  2096  2097  2098  2099  2100
# 53  91.4  91.5  91.7  91.8  91.9  92.0  92.1  92.2  92.3
#
# [1 rows x 302 columns]

# %%
spain_serie = df.set_index('country').loc['Spain']

spain_serie.plot()
plt.title('Spain Life expectancy Projections')
plt.xlabel('Life expectancy')
plt.ylabel('Year')
plt.show()

# %%
df = pd.read_csv("../population_total.csv")
df
# Out:
# La ejecución de celdas con 'Python 3.14.4' requiere el paquete ipykernel.
#
# Instale "ipykernel" en el entorno de Python.
#
# Comando: "/home/agustin/Documents/42school/piscine-python/py02/ex01/.venv/bin/python -m pip install ipykernel -U --user --force-reinstall"
